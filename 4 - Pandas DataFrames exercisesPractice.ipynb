# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       NaN
# NaN  None

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       NaN
# NaN  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df = pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-2314b6adc0fc> in <module>()
#       1 #marvel_df = marvel_df.drop(columns=['name'])
# ----> 2 marvel_df = marvel_df.drop(['name'], axis=1)
#       3 marvel_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['name'] not found in axis"

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-408a8e9911fe> in <module>()
#       1 # your code goes here
# ----> 2 marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
#       3 marvel_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Namor' 'Hank Pym'] not found in axis"

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[:5,]['sex'].to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[1:-1].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0,-1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df['Vision', 'first_appearance'] = 1964
marvel_df
# Out:
#                      sex  first_appearance  (Vision, first_appearance)
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df
# Out:
#                      sex  first_appearance  (Vision, first_appearance)
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']
marvel_df
# Out:
#                      sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Invisible Woman            54
# Storm                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Scarlet Witch              54
# Wasp                       54
# Black Widow                54
# Vision                     54

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df
# Out:
#                      sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Invisible Woman            54
# Storm                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Scarlet Witch              54
# Wasp                       54
# Black Widow                54
# Vision                     54

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask = marvel_df['sex'] == 'female'
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask = marvel_df['sex'] == 'male'
marvel_df[mask]
# Out:
#                    sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man        male              1964                        1964
# Captain America   male              1964                        1964
# Wolverine         male              1964                        1964
# Iron Man          male              1964                        1964
# Thor              male              1964                        1964
# Thing             male              1964                        1964
# Mister Fantastic  male              1964                        1964
# Hulk              male              1964                        1964
# Beast             male              1964                        1964
# Hawkeye           male              1964                        1964
# Daredevil         male              1964                        1964
# Doctor Strange    male              1964                        1964
# Vision            male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Vision                     54

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]
# Out:
#                    sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man        male              1964                        1964
# Captain America   male              1964                        1964
# Wolverine         male              1964                        1964
# Iron Man          male              1964                        1964
# Thor              male              1964                        1964
# Thing             male              1964                        1964
# Mister Fantastic  male              1964                        1964
# Hulk              male              1964                        1964
# Beast             male              1964                        1964
# Hawkeye           male              1964                        1964
# Daredevil         male              1964                        1964
# Doctor Strange    male              1964                        1964
# Vision            male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Vision                     54

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
mask = marvel_df['first_appearance'] > 1970
marvel_df[mask]
# Out:
# Empty DataFrame
# Columns: [sex, first_appearance, (Vision, first_appearance), years_since]
# Index: []

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
# Empty DataFrame
# Columns: [sex, first_appearance, (Vision, first_appearance), years_since]
# Index: []

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)
marvel_df[mask]
# Out:
# Empty DataFrame
# Columns: [sex, first_appearance, (Vision, first_appearance), years_since]
# Index: []

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]
# Out:
# Empty DataFrame
# Columns: [sex, first_appearance, (Vision, first_appearance), years_since]
# Index: []

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
# Out:
#        first_appearance  (Vision, first_appearance)  years_since
# count              18.0                        18.0         18.0
# mean             1964.0                      1964.0         54.0
# std                 0.0                         0.0          0.0
# min              1964.0                      1964.0         54.0
# 25%              1964.0                      1964.0         54.0
# 50%              1964.0                      1964.0         54.0
# 75%              1964.0                      1964.0         54.0
# max              1964.0                      1964.0         54.0

# %%
marvel_df.describe()
# Out:
#        first_appearance  (Vision, first_appearance)  years_since
# count              18.0                        18.0         18.0
# mean             1964.0                      1964.0         54.0
# std                 0.0                         0.0          0.0
# min              1964.0                      1964.0         54.0
# 25%              1964.0                      1964.0         54.0
# 50%              1964.0                      1964.0         54.0
# 75%              1964.0                      1964.0         54.0
# max              1964.0                      1964.0         54.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].mean()
# Out:
# 1964.0

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()
# Out:
# 1964.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.min()
# Out:
# 1964

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()
# Out:
# 1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#                      sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Invisible Woman            54
# Storm                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Scarlet Witch              54
# Wasp                       54
# Black Widow                54
# Vision                     54

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#                      sex  first_appearance  (Vision, first_appearance)  \
# name
# Spider-Man          male              1964                        1964
# Captain America     male              1964                        1964
# Wolverine           male              1964                        1964
# Iron Man            male              1964                        1964
# Thor                male              1964                        1964
# Thing               male              1964                        1964
# Mister Fantastic    male              1964                        1964
# Hulk                male              1964                        1964
# Beast               male              1964                        1964
# Invisible Woman   female              1964                        1964
# Storm             female              1964                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1964                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1964                        1964
# Black Widow       female              1964                        1964
# Vision              male              1964                        1964
#
#                   years_since
# name
# Spider-Man                 54
# Captain America            54
# Wolverine                  54
# Iron Man                   54
# Thor                       54
# Thing                      54
# Mister Fantastic           54
# Hulk                       54
# Beast                      54
# Invisible Woman            54
# Storm                      54
# Hawkeye                    54
# Daredevil                  54
# Doctor Strange             54
# Scarlet Witch              54
# Wasp                       54
# Black Widow                54
# Vision                     54

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#     level_0  index              name     sex  first_appearance  \
# 0         0      0        Spider-Man    male              1964
# 1         1      1   Captain America    male              1964
# 2         2      2         Wolverine    male              1964
# 3         3      3          Iron Man    male              1964
# 4         4      4              Thor    male              1964
# 5         5      5             Thing    male              1964
# 6         6      6  Mister Fantastic    male              1964
# 7         7      7              Hulk    male              1964
# 8         8      8             Beast    male              1964
# 9         9      9   Invisible Woman  female              1964
# 10       10     10             Storm  female              1964
# 11       11     11           Hawkeye    male              1964
# 12       12     12         Daredevil    male              1964
# 13       13     13    Doctor Strange    male              1964
# 14       14     14     Scarlet Witch  female              1964
# 15       15     15              Wasp  female              1964
# 16       16     16       Black Widow  female              1964
# 17       17     17            Vision    male              1964
#
#     (Vision, first_appearance)  years_since
# 0                         1964           54
# 1                         1964           54
# 2                         1964           54
# 3                         1964           54
# 4                         1964           54
# 5                         1964           54
# 6                         1964           54
# 7                         1964           54
# 8                         1964           54
# 9                         1964           54
# 10                        1964           54
# 11                        1964           54
# 12                        1964           54
# 13                        1964           54
# 14                        1964           54
# 15                        1964           54
# 16                        1964           54
# 17                        1964           54

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-07262d6a401f> in <module>()
# ----> 1 marvel_df = marvel_df.reset_index()
#       2
#       3 marvel_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.plot()

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 0.,  0.,  0.,  0.,  0., 18.,  0.,  0.,  0.,  0.]),
#  array([1963.5, 1963.6, 1963.7, 1963.8, 1963.9, 1964. , 1964.1, 1964.2,
#         1964.3, 1964.4, 1964.5]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 0.,  0.,  0.,  0.,  0., 18.,  0.,  0.,  0.,  0.]),
#  array([1963.5, 1963.6, 1963.7, 1963.8, 1963.9, 1964. , 1964.1, 1964.2,
#         1964.3, 1964.4, 1964.5]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
